# %% [markdown]
# ## **MÔI TRƯỜNG TRIỂN KHAI ỨNG DỤNG**

# %%
# !pip install proplot
# !pip install kmodes

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn.mixture import GaussianMixture
from sklearn.manifold import TSNE

import warnings
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: proplot in /usr/local/lib/python3.10/dist-packages (0.9.7)
# Requirement already satisfied: matplotlib<3.5.0,>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from proplot) (3.4.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.5.0,>=3.3.0->proplot) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.5.0,>=3.3.0->proplot) (1.4.5)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.5.0,>=3.3.0->proplot) (1.25.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.5.0,>=3.3.0->proplot) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.5.0,>=3.3.0->proplot) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.5.0,>=3.3.0->proplot) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<3.5.0,>=3.3.0->proplot) (1.16.0)
# Requirement already satisfied: kmodes in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.10/dist-packages (from kmodes) (1.25.2)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from kmodes) (1.2.2)
# Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python3.10/dist-packages (from kmodes) (1.11.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from kmodes) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.0->kmodes) (3.5.0)

# %%
# # Kết nối Google Drive
# from google.colab import drive
# drive.mount("/content/gdrive", force_remount = True)
# folder = '/content/gdrive/MyDrive/Colab Notebooks'
# Out:
# Mounted at /content/gdrive

# %%
# Tập dữ liệu
df = pd.read_csv('marketing_campaign.csv','\t')
df.head()
# Out:
#      ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0  5524        1957  Graduation         Single  58138.0        0         0
# 1  2174        1954  Graduation         Single  46344.0        1         1
# 2  4141        1965  Graduation       Together  71613.0        0         0
# 3  6182        1984  Graduation       Together  26646.0        1         0
# 4  5324        1981         PhD        Married  58293.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  NumCatalogPurchases  NumStorePurchases  \
# 0  04-09-2012       58       635  ...                   10                  4
# 1  08-03-2014       38        11  ...                    1                  2
# 2  21-08-2013       26       426  ...                    2                 10
# 3  10-02-2014       26        11  ...                    0                  4
# 4  19-01-2014       94       173  ...                    3                  6
#
#    NumWebVisitsMonth  AcceptedCmp1  AcceptedCmp2  AcceptedCmp3  AcceptedCmp4  \
# 0                  7             0             0             0             0
# 1                  5             0             0             0             0
# 2                  4             0             0             0             0
# 3                  6             0             0             0             0
# 4                  5             0             0             0             0
#
#    AcceptedCmp5  Complain  Response
# 0             0         0         1
# 1             0         0         0
# 2             0         0         0
# 3             0         0         0
# 4             0         0         0
#
# [5 rows x 27 columns]

# %% [markdown]
# ## **TIỀN XỬ LÝ DỮ LIỆU**

# %% [markdown]
# ### Xử lý missing values

# %%
# Kiểm tra có dữ liệu bị thiếu hay không
df.isnull().sum().sort_values(ascending=False)
# Out:
# Income                 24
# ID                      0
# MntGoldProds            0
# Complain                0
# AcceptedCmp5            0
# AcceptedCmp4            0
# AcceptedCmp3            0
# AcceptedCmp2            0
# AcceptedCmp1            0
# NumWebVisitsMonth       0
# NumStorePurchases       0
# NumCatalogPurchases     0
# NumWebPurchases         0
# NumDealsPurchases       0
# MntSweetProducts        0
# Year_Birth              0
# MntFishProducts         0
# MntMeatProducts         0
# MntFruits               0
# MntWines                0
# Recency                 0
# Dt_Customer             0
# Teenhome                0
# Kidhome                 0
# Marital_Status          0
# Education               0
# Response                0
# dtype: int64

# %%
#To remove the NA values
df = df.dropna()
print("The total number of data-points after removing the rows with missing values are:", len(df))
# Out:
# The total number of data-points after removing the rows with missing values are: 2216

# %% [markdown]
# ### Thêm biến mới

# %%
df['Age'] = 2024 - df['Year_Birth']

print(df["Age"])

# Thêm cột Kids có giá trị bằng tổng giá trị cột Kidhome và Teenhome
df['Kids'] = df['Kidhome'] + df['Teenhome']
# Thêm cột Expenses có giá trị bằng tổng giá trị các cột sản phẩm
df['Expenses'] = df['MntWines'] + df['MntFruits'] + df['MntMeatProducts'] + df['MntFishProducts'] + df['MntSweetProducts'] + df['MntGoldProds']

# In ra kết quả của hai cột mới
print("Dữ liệu sau khi thêm cột 'Kids':")
print(df['Kids'])

print("\nDữ liệu sau khi thêm cột 'Expenses':")
print(df['Expenses'])
# Out:
# 0       67
# 1       70
# 2       59
# 3       40
# 4       43
#         ..
# 2235    57
# 2236    78
# 2237    43
# 2238    68
# 2239    70
# Name: Age, Length: 2216, dtype: int64
# Dữ liệu sau khi thêm cột 'Kids':
# 0       0
# 1       2
# 2       0
# 3       1
# 4       1
#        ..
# 2235    1
# 2236    3
# 2237    0
# 2238    1
# 2239    2
# Name: Kids, Length: 2216, dtype: int64
#
# Dữ liệu sau khi thêm cột 'Expenses':
# 0       1617
# 1         27
# 2        776
# 3         53
# 4        422
#         ...
# 2235    1341
# 2236     444
# 2237    1241
# 2238     843
# 2239     172
# Name: Expenses, Length: 2216, dtype: int64

# %% [markdown]
# ### Làm sạch một số biến

# %%
# Kiểm tra cột Marital_Status
df['Marital_Status'].value_counts()
# Out:
# Marital_Status
# Married     857
# Together    573
# Single      471
# Divorced    232
# Widow        76
# Alone         3
# Absurd        2
# YOLO          2
# Name: count, dtype: int64

# %%
# Đổi tên các giá trị trong cột
df['Marital_Status'] = df['Marital_Status'].str.replace('Married', 'In relationship')
df['Marital_Status'] = df['Marital_Status'].str.replace('Together', 'In relationship')
df['Marital_Status'] = df['Marital_Status'].str.replace('Divorced', 'Single')
df['Marital_Status'] = df['Marital_Status'].str.replace('Widow', 'Single')
df['Marital_Status'] = df['Marital_Status'].str.replace('Absurd', 'Single')
df['Marital_Status'] = df['Marital_Status'].str.replace('Alone', 'Single')
df['Marital_Status'] = df['Marital_Status'].str.replace('YOLO', 'Single')

# Mã hóa nhãn (Label Encoding)
df['Marital_Status'] = df['Marital_Status'].map({'In relationship': 1, 'Single': 0})

# Kiểm tra lại các giá trị sau khi thay đổi
df['Marital_Status'].value_counts()
# Out:
# Marital_Status
# 1    1430
# 0     786
# Name: count, dtype: int64

# %%
# Kiểm tra cột Education
df['Education'].value_counts()
# Out:
# Education
# Graduation    1116
# PhD            481
# Master         365
# 2n Cycle       200
# Basic           54
# Name: count, dtype: int64

# %%
# Đổi giá trị '2n Cycle' thành 'Master'
df['Education'] = df['Education'].str.replace('2n Cycle', 'Master')

# Mã hóa nhãn (Label Encoding)
education_mapping = {
    'Graduation': 1,
    'PhD': 2,
    'Master': 3,
    'Basic': 0
}

df['Education'] = df['Education'].map(education_mapping)

# Kiểm tra lại các giá trị sau khi thay đổi
print(df['Education'].value_counts())
# Out:
# Education
# 1    1116
# 3     565
# 2     481
# 0      54
# Name: count, dtype: int64

# %%
df.columns   # Kiểm tra các cột hiện có
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4',
#        'AcceptedCmp5', 'Complain', 'Response', 'Age', 'Kids', 'Expenses'],
#       dtype='object')

# %%
# Loại bỏ những cột không sử dụng
df = df.drop(columns=[
       'ID', 'Year_Birth', 'Dt_Customer', 'Kidhome', 'Teenhome', 'Recency', 'NumDealsPurchases',
       'NumWebPurchases','NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth', 'AcceptedCmp1',
       'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response',
       ])

# %%
# Đổi tên lại các cột
df.columns = ['Education', 'Marital_Status', 'Income', 'Wines', 'Fruits', 'Meat', 'Fish', 'Sweet', 'Gold',  'Age', 'Children', 'Expenses']

print(df)
# Out:
#       Education  Marital_Status   Income  Wines  Fruits  Meat  Fish  Sweet  \
# 0             1               0  58138.0    635      88   546   172     88
# 1             1               0  46344.0     11       1     6     2      1
# 2             1               1  71613.0    426      49   127   111     21
# 3             1               1  26646.0     11       4    20    10      3
# 4             2               1  58293.0    173      43   118    46     27
# ...         ...             ...      ...    ...     ...   ...   ...    ...
# 2235          1               1  61223.0    709      43   182    42    118
# 2236          2               1  64014.0    406       0    30     0      0
# 2237          1               0  56981.0    908      48   217    32     12
# 2238          3               1  69245.0    428      30   214    80     30
# 2239          2               1  52869.0     84       3    61     2      1
#
#       Gold  Age  Children  Expenses
# 0       88   67         0      1617
# 1        6   70         2        27
# 2       42   59         0       776
# 3        5   40         1        53
# 4       15   43         1       422
# ...    ...  ...       ...       ...
# 2235   247   57         1      1341
# 2236     8   78         3       444
# 2237    24   43         0      1241
# 2238    61   68         1       843
# 2239    21   70         2       172
#
# [2216 rows x 12 columns]

# %%
df.describe() #Tạo bảng tóm tắt thống kê
# Out:
#          Education  Marital_Status         Income        Wines       Fruits  \
# count  2216.000000     2216.000000    2216.000000  2216.000000  2216.000000
# mean      1.702617        0.645307   52247.251354   305.091606    26.356047
# std       0.876332        0.478528   25173.076661   337.327920    39.793917
# min       0.000000        0.000000    1730.000000     0.000000     0.000000
# 25%       1.000000        0.000000   35303.000000    24.000000     2.000000
# 50%       1.000000        1.000000   51381.500000   174.500000     8.000000
# 75%       3.000000        1.000000   68522.000000   505.000000    33.000000
# max       3.000000        1.000000  666666.000000  1493.000000   199.000000
#
#               Meat         Fish        Sweet         Gold          Age  \
# count  2216.000000  2216.000000  2216.000000  2216.000000  2216.000000
# mean    166.995939    37.637635    27.028881    43.965253    55.179603
# std     224.283273    54.752082    41.072046    51.815414    11.985554
# min       0.000000     0.000000     0.000000     0.000000    28.000000
# 25%      16.000000     3.000000     1.000000     9.000000    47.000000
# 50%      68.000000    12.000000     8.000000    24.500000    54.000000
# 75%     232.250000    50.000000    33.000000    56.000000    65.000000
# max    1725.000000   259.000000   262.000000   321.000000   131.000000
#
#           Children     Expenses
# count  2216.000000  2216.000000
# mean      0.947202   607.075361
# std       0.749062   602.900476
# min       0.000000     5.000000
# 25%       0.000000    69.000000
# 50%       1.000000   396.500000
# 75%       1.000000  1048.000000
# max       3.000000  2525.000000

# %% [markdown]
# ### Xử lý outliers

# %%
#Vẽ biểu đồ hộp (box plot) cho biến 'Income' từ dữ liệu df
sns.set(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'axes.grid' : False})
fig = plt.figure(figsize=(6, 8))
sns.boxplot(data=df['Income'], palette='viridis', flierprops={'markeredgecolor': 'white'})
plt.title('Box Plot for Income', color='#FFC300', size= 20)
plt.tick_params(axis='x', colors='white')
plt.tick_params(axis='y', colors='white')
plt.show()


#Vẽ biểu đồ hộp (box plot) cho biến 'Income' từ dữ liệu df
sns.set(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'axes.grid' : False})
fig = plt.figure(figsize=(6, 8))
sns.boxplot(data=df['Age'], palette='viridis', flierprops={'markeredgecolor': 'white'})
plt.title('Box Plot for Age', color='#FFC300', size= 20)
plt.tick_params(axis='x', colors='white')
plt.tick_params(axis='y', colors='white')
plt.show()

# %%
from scipy import stats
import numpy as np

# Tạo một DataFrame mới chỉ chứa các cột cần xét
df_subset = df[['Income', 'Age']]

# Tính toán z-scores cho từng cột trong df_subset
z_scores = np.abs(stats.zscore(df_subset))

# Lọc các hàng có giá trị z-score nằm trong khoảng [-3, 3] cho cả hai cột
filtered_entries = (z_scores < 3).all(axis=1)

# Tạo một DataFrame mới với các hàng đã lọc
df1 = df[filtered_entries]
df1.reset_index(inplace=True, drop=True)

len(df1)


# #Vẽ biểu đồ hộp (box plot) cho biến 'Income' từ dữ liệu df
# sns.set(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'axes.grid' : False})
# fig = plt.figure(figsize=(6, 8))
# sns.boxplot(data=df1['Income'], palette='viridis', flierprops={'markeredgecolor': 'white'})
# plt.title('Box Plot for Income', color='#FFC300', size= 20)
# plt.tick_params(axis='x', colors='white')
# plt.tick_params(axis='y', colors='white')
# plt.show()


# #Vẽ biểu đồ hộp (box plot) cho biến 'Income' từ dữ liệu df
# sns.set(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'axes.grid' : False})
# fig = plt.figure(figsize=(6, 8))
# sns.boxplot(data=df1['Age'], palette='viridis', flierprops={'markeredgecolor': 'white'})
# plt.title('Box Plot for Age', color='#FFC300', size= 20)
# plt.tick_params(axis='x', colors='white')
# plt.tick_params(axis='y', colors='white')
# plt.show()
# Out:
# 2205

# %%
from sklearn.preprocessing import MinMaxScaler

# Tạo một scaler
scaler = MinMaxScaler()

# Scale dữ liệu về khoảng 0-1
df1_scaled = scaler.fit_transform(df1)

# Chuyển đổi dữ liệu scaled thành DataFrame
df1_scaled = pd.DataFrame(df1_scaled, columns=df1.columns)

# Kiểm tra kết quả
df1_scaled.head()
# Out:
#    Education  Marital_Status    Income     Wines    Fruits      Meat  \
# 0   0.333333             0.0  0.503625  0.425318  0.442211  0.316522
# 1   0.333333             0.0  0.398325  0.007368  0.005025  0.003478
# 2   0.333333             1.0  0.623933  0.285332  0.246231  0.073623
# 3   0.333333             1.0  0.222456  0.007368  0.020101  0.011594
# 4   0.666667             1.0  0.505009  0.115874  0.216080  0.068406
#
#        Fish     Sweet      Gold       Age  Children  Expenses
# 0  0.664093  0.335878  0.274143  0.696429  0.000000  0.639683
# 1  0.007722  0.003817  0.018692  0.750000  0.666667  0.008730
# 2  0.428571  0.080153  0.130841  0.553571  0.000000  0.305952
# 3  0.038610  0.011450  0.015576  0.214286  0.333333  0.019048
# 4  0.177606  0.103053  0.046729  0.267857  0.333333  0.165476

# %% [markdown]
# #AUTOENCODER

# %%
import keras
from keras.models import Model
from keras.layers import Input, Dense, Dropout
from keras.regularizers import l1, l2
from keras.callbacks import EarlyStopping

keras.utils.set_random_seed(43)
# Điều chỉnh kích thước không gian mã hóa
input_dim = df1_scaled.shape[1]
encoding_dim = 4 # Thử tăng kích thước không gian mã hóa

input_layer = Input(shape=(input_dim,))
encoded = Dense(10, activation='relu', activity_regularizer=l1(1e-5))(input_layer)
encoded = Dropout(0.2)(encoded)
encoded = Dense(8, activation='relu')(encoded)
encoded = Dense(encoding_dim, activation='relu')(encoded)
decoded = Dense(8, activation='relu')(encoded)
decoded = Dense(10, activation='relu')(decoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(input_layer, decoded)
encoder = Model(input_layer, encoded)

autoencoder.compile(optimizer='adam', loss='huber_loss')

# Sử dụng early stopping để tránh overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Huấn luyện mô hình Autoencoder
history = autoencoder.fit(df1_scaled, df1_scaled, epochs=100, batch_size=256, shuffle=True, validation_split=0.2, callbacks=[early_stopping])

# Lấy dữ liệu đã mã hóa
df1_predict = encoder.predict(df1_scaled)

print(df1_predict)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 2s 46ms/step - loss: 0.0684 - val_loss: 0.0674
# Epoch 2/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0678 - val_loss: 0.0668
# Epoch 3/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0672 - val_loss: 0.0662
# Epoch 4/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0665 - val_loss: 0.0654
# Epoch 5/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0657 - val_loss: 0.0646
# Epoch 6/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0648 - val_loss: 0.0637
# Epoch 7/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0639 - val_loss: 0.0627
# Epoch 8/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0627 - val_loss: 0.0614
# Epoch 9/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0614 - val_loss: 0.0600
# Epoch 10/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0598 - val_loss: 0.0583
# Epoch 11/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0580 - val_loss: 0.0564
# Epoch 12/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0559 - val_loss: 0.0543
# Epoch 13/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0536 - val_loss: 0.0519
# Epoch 14/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0511 - val_loss: 0.0494
# Epoch 15/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0484 - val_loss: 0.0468
# Epoch 16/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0456 - val_loss: 0.0442
# Epoch 17/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0431 - val_loss: 0.0417
# Epoch 18/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0406 - val_loss: 0.0395
# Epoch 19/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0383 - val_loss: 0.0375
# Epoch 20/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0363 - val_loss: 0.0357
# Epoch 21/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0345 - val_loss: 0.0341
# Epoch 22/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0331 - val_loss: 0.0326
# Epoch 23/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0317 - val_loss: 0.0313
# Epoch 24/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0305 - val_loss: 0.0302
# Epoch 25/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0294 - val_loss: 0.0292
# Epoch 26/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0286 - val_loss: 0.0284
# Epoch 27/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0279 - val_loss: 0.0277
# Epoch 28/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0273 - val_loss: 0.0271
# Epoch 29/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0268 - val_loss: 0.0266
# Epoch 30/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0264 - val_loss: 0.0262
# Epoch 31/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0260 - val_loss: 0.0259
# Epoch 32/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0258 - val_loss: 0.0256
# Epoch 33/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0255 - val_loss: 0.0253
# Epoch 34/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0251 - val_loss: 0.0251
# Epoch 35/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0249 - val_loss: 0.0248
# Epoch 36/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0247 - val_loss: 0.0246
# Epoch 37/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0245 - val_loss: 0.0245
# Epoch 38/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0243 - val_loss: 0.0242
# Epoch 39/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0241 - val_loss: 0.0240
# Epoch 40/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0239 - val_loss: 0.0239
# Epoch 41/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0238 - val_loss: 0.0237
# Epoch 42/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0237 - val_loss: 0.0236
# Epoch 43/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0236 - val_loss: 0.0234
# Epoch 44/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0234 - val_loss: 0.0233
# Epoch 45/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0233 - val_loss: 0.0232
# Epoch 46/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0232 - val_loss: 0.0231
# Epoch 47/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0230 - val_loss: 0.0229
# Epoch 48/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0229 - val_loss: 0.0228
# Epoch 49/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0228 - val_loss: 0.0226
# Epoch 50/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0227 - val_loss: 0.0225
# Epoch 51/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0225 - val_loss: 0.0223
# Epoch 52/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0224 - val_loss: 0.0221
# Epoch 53/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0222 - val_loss: 0.0219
# Epoch 54/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0220 - val_loss: 0.0217
# Epoch 55/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0219 - val_loss: 0.0215
# Epoch 56/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0217 - val_loss: 0.0213
# Epoch 57/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0214 - val_loss: 0.0210
# Epoch 58/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0213 - val_loss: 0.0206
# Epoch 59/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0209 - val_loss: 0.0202
# Epoch 60/100
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0206 - val_loss: 0.0198
# Epoch 61/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0203 - val_loss: 0.0193
# Epoch 62/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0198 - val_loss: 0.0187
# Epoch 63/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0194 - val_loss: 0.0181
# Epoch 64/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0192 - val_loss: 0.0175
# Epoch 65/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0186 - val_loss: 0.0168
# Epoch 66/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0182 - val_loss: 0.0163
# Epoch 67/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0177 - val_loss: 0.0158
# Epoch 68/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0174 - val_loss: 0.0153
# Epoch 69/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0168 - val_loss: 0.0149
# Epoch 70/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0166 - val_loss: 0.0146
# Epoch 71/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0161 - val_loss: 0.0142
# Epoch 72/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0158 - val_loss: 0.0139
# Epoch 73/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0153 - val_loss: 0.0137
# Epoch 74/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0153 - val_loss: 0.0134
# Epoch 75/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0149 - val_loss: 0.0131
# Epoch 76/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0146 - val_loss: 0.0129
# Epoch 77/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0143 - val_loss: 0.0127
# Epoch 78/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0142 - val_loss: 0.0125
# Epoch 79/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0138 - val_loss: 0.0124
# Epoch 80/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0138 - val_loss: 0.0122
# Epoch 81/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0137 - val_loss: 0.0121
# Epoch 82/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0135 - val_loss: 0.0119
# Epoch 83/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0133 - val_loss: 0.0118
# Epoch 84/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0132 - val_loss: 0.0117
# Epoch 85/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0133 - val_loss: 0.0116
# Epoch 86/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0131 - val_loss: 0.0115
# Epoch 87/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0129 - val_loss: 0.0115
# Epoch 88/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0128 - val_loss: 0.0114
# Epoch 89/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0127 - val_loss: 0.0114
# Epoch 90/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0128 - val_loss: 0.0113
# Epoch 91/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0124 - val_loss: 0.0112
# Epoch 92/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0128 - val_loss: 0.0112
# Epoch 93/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0128 - val_loss: 0.0111
# Epoch 94/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0125 - val_loss: 0.0111
# Epoch 95/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0123 - val_loss: 0.0111
# Epoch 96/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0123 - val_loss: 0.0110
# Epoch 97/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0123 - val_loss: 0.0110
# Epoch 98/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0123 - val_loss: 0.0109
# Epoch 99/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0122 - val_loss: 0.0109
# Epoch 100/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0122 - val_loss: 0.0109
# 69/69 [==============================] - 0s 2ms/step
# [[1.6159613e+00 1.5540932e+00 1.5681615e+00 3.4426749e-03]
#  [0.0000000e+00 1.5934982e+00 0.0000000e+00 3.2133818e+00]
#  [2.2014985e+00 0.0000000e+00 0.0000000e+00 1.9348121e+00]
#  ...
#  [9.2003262e-01 1.1086538e+00 7.1707302e-01 3.4406537e-01]
#  [2.5857425e+00 0.0000000e+00 0.0000000e+00 3.0485644e+00]
#  [2.1906734e+00 4.0287706e-01 0.0000000e+00 5.9512572e+00]]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
np.savetxt("/content/drive/MyDrive/pred.csv", df1_predict, delimiter=",", fmt="%f")

# %% [markdown]
# # **MÔ HÌNH PHÂN CỤM**

# %% [markdown]
# ##Elbow

# %% [markdown]
# ### K-Means Clustering

# %%
# Elbow method for KMeans
K = range(1, 10)
cost_kmeans = []
for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df1_predict)
    cost_kmeans.append(kmeans.inertia_)

# Plotting the elbow for KMeans
sns.set(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'axes.grid': False})

fig, ax = plt.subplots(figsize=(10, 8))
plt.plot(K, cost_kmeans, 'bo-', color='#FFC300')
plt.xlabel('k', color='white', size=14)
plt.ylabel('Distortion', color='white', size=14)
plt.tick_params(axis='x', colors='white')
plt.tick_params(axis='y', colors='white')
plt.title('Xác định k theo phương pháp Elbow cho KMeans', color='#FFC300', size=20)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.show()

# %% [markdown]
# ### Hierarchical Clustering

# %%
from scipy.spatial.distance import cdist
# Elbow method for Hierarchical Clustering
linkage_matrix = linkage(df1_predict, method='ward')
cost_hierarchical = []
for k in K:
    clusters = fcluster(linkage_matrix, k, criterion='maxclust')
    cluster_centers = np.array([df1_predict[clusters == i].mean(axis=0) for i in range(1, k+1)])
    cost_hierarchical.append(np.sum(np.min(cdist(df1_predict, cluster_centers, 'euclidean'), axis=1)) / df1_predict.shape[0])

# Plotting the elbow for Hierarchical Clustering
fig, ax = plt.subplots(figsize=(10, 8))
plt.plot(K, cost_hierarchical, 'bo-', color='#FFC300')
plt.xlabel('k', color='white', size=14)
plt.ylabel('Distortion', color='white', size=14)
plt.tick_params(axis='x', colors='white')
plt.tick_params(axis='y', colors='white')
plt.title('Xác định k theo phương pháp Elbow cho Hierarchical Clustering', color='#FFC300', size=20)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.show()

# %% [markdown]
# ### GMM Clustering

# %%
# Elbow method for GMM using WCSS
cost_gmm = []
for k in K:
    gmm = GaussianMixture(n_components=k, random_state=42)
    gmm.fit(df1_predict)
    labels = gmm.predict(df1_predict)
    wcss = np.sum(np.min(cdist(df1_predict, gmm.means_, 'euclidean'), axis=1))
    cost_gmm.append(wcss)

# Plotting the elbow for GMM
fig, ax = plt.subplots(figsize=(10, 8))
plt.plot(K, cost_gmm, 'bo-', color='#FFC300')
plt.xlabel('k', color='white', size=14)
plt.ylabel('Distortion', color='white', size=14)
plt.tick_params(axis='x', colors='white')
plt.tick_params(axis='y', colors='white')
plt.title('Xác định k theo phương pháp Elbow cho GMM', color='#FFC300', size=20)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.show()

# %% [markdown]
# ##Silhouette score

# %% [markdown]
# ### K-Means Clustering

# %%
def silhouette_score_kmeans(df, labels):
    return silhouette_score(df, labels)

silhouette_scores_kmeans = []

# Lặp qua các số lượng cụm từ 2 đến 10 cho K-Means
K = range(2, 10)
for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    clusters = kmeans.fit_predict(df1_predict)
    silhouette_avg = silhouette_score_kmeans(df1_predict, clusters)
    silhouette_scores_kmeans.append(silhouette_avg)


# Visualize Silhouette Scores for K-Means

plt.figure(figsize=(10, 8))
plt.plot(K, silhouette_scores_kmeans, 'bo-', color='#FFC300')
plt.xlabel('k', color='white', size=14)
plt.ylabel('Silhouette Score', color='white', size=14)
plt.title('Silhouette Score for K-Means Clustering', color='#FFC300', size=20)
plt.show()

# %% [markdown]
# ### Hierarchical Clustering

# %%
silhouette_scores_hierarchical = []

for k in K:
    hierarchical = linkage(df1_predict, method='ward')
    clusters = fcluster(hierarchical, k, criterion='maxclust')
    silhouette_avg = silhouette_score(df1_predict, clusters)
    silhouette_scores_hierarchical.append(silhouette_avg)


plt.figure(figsize=(10, 8))
plt.plot(K, silhouette_scores_hierarchical, 'bo-', color='#FFC300')
plt.xlabel('k', color='white', size=14)
plt.ylabel('Silhouette Score', color='white', size=14)
plt.title('Silhouette Score for Hierarchical Clustering', color='#FFC300', size=20)
plt.show()

# %% [markdown]
# ### GMM Clustering

# %%
silhouette_scores_gmm = []

for k in K:
    gmm = GaussianMixture(n_components=k, random_state=42)
    clusters = gmm.fit_predict(df1_predict)
    silhouette_avg = silhouette_score(df1_predict, clusters)
    silhouette_scores_gmm.append(silhouette_avg)


plt.figure(figsize=(10, 8))
plt.plot(K, silhouette_scores_gmm, 'bo-', color='#FFC300')
plt.xlabel('k', color='white', size=14)
plt.ylabel('Silhouette Score', color='white', size=14)
plt.title('Silhouette Score for GMM Clustering', color='#FFC300', size=20)
plt.show()

# %% [markdown]
# ##Chọn cụm và mô hình tối ưu

# %%
# Silhouette scores đã được tính toán từ trước
print("Silhouette Scores for K-Means:", silhouette_scores_kmeans)
print("Silhouette Scores for Hierarchical Clustering:", silhouette_scores_hierarchical)
print("Silhouette Scores for GMM:", silhouette_scores_gmm)

optimal_k_kmeans = silhouette_scores_kmeans.index(max(silhouette_scores_kmeans)) + 2
optimal_k_hierarchical = silhouette_scores_hierarchical.index(max(silhouette_scores_hierarchical)) + 2
optimal_k_gmm = silhouette_scores_gmm.index(max(silhouette_scores_gmm)) + 2

print("Optimal number of clusters for K-Means:", optimal_k_kmeans)
print("Optimal number of clusters for Hierarchical Clustering:", optimal_k_hierarchical)
print("Optimal number of clusters for GMM:", optimal_k_gmm)

# Tìm mô hình có silhouette score cao nhất
best_score = max(max(silhouette_scores_kmeans), max(silhouette_scores_hierarchical), max(silhouette_scores_gmm))

if best_score in silhouette_scores_kmeans:
    best_model = "K-Means"
elif best_score in silhouette_scores_hierarchical:
    best_model = "Hierarchical Clustering"
else:
    best_model = "GMM"

print("The best model based on silhouette score is:", best_model)
# Out:
# Silhouette Scores for K-Means: [0.56745833, 0.54727405, 0.6261154, 0.5852166, 0.51631236, 0.4676706, 0.43319914, 0.40418237]
# Silhouette Scores for Hierarchical Clustering: [0.55449504, 0.52167016, 0.6067686, 0.5692311, 0.5039241, 0.44911304, 0.4128871, 0.38520318]
# Silhouette Scores for GMM: [0.39074436, 0.3514745, 0.593562, 0.49066797, 0.4302168, 0.3723555, 0.3257387, 0.2647676]
# Optimal number of clusters for K-Means: 4
# Optimal number of clusters for Hierarchical Clustering: 4
# Optimal number of clusters for GMM: 4
# The best model based on silhouette score is: K-Means

# %% [markdown]
# ##Trực quan hóa các cụm

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score

# K-Means Clustering
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans_clusters = kmeans.fit_predict(df1_predict)

# Hierarchical Clustering
hierarchical = linkage(df1_predict, method='ward')
hierarchical_clusters = fcluster(hierarchical, 4, criterion='maxclust')

# GMM Clustering
gmm = GaussianMixture(n_components=4, random_state=42)
gmm_clusters = gmm.fit_predict(df1_predict)

# Calculate evaluation metrics
def evaluate_clustering(labels, data):
    silhouette = silhouette_score(data, labels)
    davies_bouldin = davies_bouldin_score(data, labels)
    calinski_harabasz = calinski_harabasz_score(data, labels)
    return silhouette, davies_bouldin, calinski_harabasz

kmeans_scores = evaluate_clustering(kmeans_clusters, df1_predict)
hierarchical_scores = evaluate_clustering(hierarchical_clusters, df1_predict)
gmm_scores = evaluate_clustering(gmm_clusters, df1_predict)

# Print evaluation results
print(f'K-Means Scores: Silhouette={kmeans_scores[0]:.4f}, Davies-Bouldin={kmeans_scores[1]:.4f}, Calinski-Harabasz={kmeans_scores[2]:.4f}')
print(f'Hierarchical Scores: Silhouette={hierarchical_scores[0]:.4f}, Davies-Bouldin={hierarchical_scores[1]:.4f}, Calinski-Harabasz={hierarchical_scores[2]:.4f}')
print(f'GMM Scores: Silhouette={gmm_scores[0]:.4f}, Davies-Bouldin={gmm_scores[1]:.4f}, Calinski-Harabasz={gmm_scores[2]:.4f}')

# Visualize Clustering Results with t-SNE
tsne = TSNE(n_components=2, perplexity=30, learning_rate=100, n_iter=5000, random_state=42)
tsne_result = tsne.fit_transform(df1_predict)

df_tsne = pd.DataFrame(tsne_result, columns=['t-SNE1', 't-SNE2'])
df_tsne['KMeans'] = kmeans_clusters
df_tsne['Hierarchical'] = hierarchical_clusters
df_tsne['GMM'] = gmm_clusters

fig, axes = plt.subplots(1, 3, figsize=(24, 8))

axes[0].scatter(df_tsne['t-SNE1'], df_tsne['t-SNE2'], c=df_tsne['KMeans'], cmap='viridis', s=50)
axes[0].set_title('K-Means Clustering', color='#FFC300')
axes[1].scatter(df_tsne['t-SNE1'], df_tsne['t-SNE2'], c=df_tsne['Hierarchical'], cmap='viridis', s=50)
axes[1].set_title('Hierarchical Clustering', color='#FFC300')
axes[2].scatter(df_tsne['t-SNE1'], df_tsne['t-SNE2'], c=df_tsne['GMM'], cmap='viridis', s=50)
axes[2].set_title('Gaussian Mixture Model Clustering', color='#FFC300')

for ax in axes:
    ax.set_xticks([])
    ax.set_yticks([])

plt.show()
# Out:
# K-Means Scores: Silhouette=0.6261, Davies-Bouldin=0.5660, Calinski-Harabasz=5238.3732
# Hierarchical Scores: Silhouette=0.6068, Davies-Bouldin=0.6184, Calinski-Harabasz=4830.7899
# GMM Scores: Silhouette=0.5936, Davies-Bouldin=0.5304, Calinski-Harabasz=3941.3979

# %%
# !pip install umap-learn
# Out:
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.10/dist-packages (0.5.6)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.58.1)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.5.12)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.4)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.41.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.5.0)

# %% [markdown]
# ##Gộp dữ liệu gốc với các cụm

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# KMeans Clustering với k tối ưu là 4
kmeans = KMeans(n_clusters=4, random_state=42)
clusters = kmeans.fit_predict(df1_predict)

# Gộp dữ liệu gốc với các cụm
df_clusters = pd.concat([df1, pd.DataFrame({'cluster': clusters})], axis=1)

df_clusters
# Out:
#       Education  Marital_Status   Income  Wines  Fruits  Meat  Fish  Sweet  \
# 0             1               0  58138.0    635      88   546   172     88
# 1             1               0  46344.0     11       1     6     2      1
# 2             1               1  71613.0    426      49   127   111     21
# 3             1               1  26646.0     11       4    20    10      3
# 4             2               1  58293.0    173      43   118    46     27
# ...         ...             ...      ...    ...     ...   ...   ...    ...
# 2200          1               1  61223.0    709      43   182    42    118
# 2201          2               1  64014.0    406       0    30     0      0
# 2202          1               0  56981.0    908      48   217    32     12
# 2203          3               1  69245.0    428      30   214    80     30
# 2204          2               1  52869.0     84       3    61     2      1
#
#       Gold  Age  Children  Expenses  cluster
# 0       88   67         0      1617        1
# 1        6   70         2        27        3
# 2       42   59         0       776        2
# 3        5   40         1        53        0
# 4       15   43         1       422        0
# ...    ...  ...       ...       ...      ...
# 2200   247   57         1      1341        2
# 2201     8   78         3       444        0
# 2202    24   43         0      1241        1
# 2203    61   68         1       843        2
# 2204    21   70         2       172        0
#
# [2205 rows x 13 columns]

# %% [markdown]
# ##Phân tích ý nghĩa cụm

# %%
# Giải thích các cụm
sns.set(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'axes.grid' : False})

for col in df_clusters:
    g = sns.FacetGrid(df_clusters, col='cluster', hue='cluster', palette='Set2')
    g.map(plt.hist, col, bins=10, ec='k')
    g.set_xticklabels(rotation=30, color='white')
    g.set_yticklabels(color='white')
    g.set_xlabels(size=15, color='white')
    g.set_titles(size=15, color='#FFC300', fontweight='bold')
    g.fig.set_figheight(5)
    plt.show()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df_clusters is your dataframe with cluster assignments
# Calculate the number of samples in each cluster and store in the variable clusters_count
clusters_count = df_clusters['cluster'].value_counts()

# Convert Series clusters_count to DataFrame and reset index
clusters_count = clusters_count.to_frame().reset_index()

clusters_count.columns = ['clusters', 'count']  # Rename columns
clusters_count = clusters_count.sort_values('clusters', ascending=True)  # Sort data in ascending order

# Define labels for clusters
labels = [f"Cluster {i}" for i in clusters_count['clusters']]

# Visualization
plt.figure(figsize=(12, 8))
mpl.rcParams['font.size'] = 17
colors = sns.color_palette('Set2')[0:len(clusters_count)]

plt.pie(clusters_count['count'],
        explode=[0.05] * len(clusters_count),
        labels=labels,
        colors=colors,
        autopct='%1.1f%%',
        textprops=dict(color="white", fontsize=19),
        counterclock=False,
        startangle=180,
        wedgeprops={"edgecolor": "gray", 'linewidth': 1}
        )
plt.axis('equal')

plt.title("Biểu đồ Phân phối phần trăm các cụm", size=25, color="#FFC300")
plt.show()

# %%
plt.style.use('default')
#Plotting countplot of clusters
pal = ["#682F2F","#B9C0C9", "#9F8A78","#F3AB60"]
pl = sns.scatterplot(data = df_clusters,x=df_clusters["Expenses"], y=df_clusters["Income"],hue=df_clusters["cluster"], palette= pal)
pl.set_title("Cluster's Profile Based On Income And Expenses")
plt.legend()
plt.show()

# %%
# Tạo một bộ dữ liệu mới từ các cột đã chọn trong DataFrame df_clusters
clusters_incomes = df_clusters[['Income', 'Expenses', 'cluster']]           # Chọn các giá trị

# Thêm một biến mới 'group' và gán giá trị từ cột 'cluster'
clusters_incomes['group'] = clusters_incomes['cluster']

# Thay đổi kiểu dữ liệu
clusters_incomes['group'] = clusters_incomes['group'].astype(str)


clusters_incomes = clusters_incomes.sort_values('group', ascending = False)    # sắp xếp dữ liệu

# Trực quan hóa
fig, ax = plt.subplots(figsize =(12, 8))

sns.scatterplot(data = clusters_incomes, x = 'Income', y = 'Expenses', hue = 'group', palette = 'Set2', alpha=0.6)

# Đặt tên cho nhãn các trục
plt.xlabel('Income', color = 'white', size = 14);
plt.ylabel('Expenses', color = 'white', size = 14);

# Ẩn các đường viền bên phải và trên cùng
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.tick_params(colors='white')
plt.legend(labelcolor = 'white', frameon=False, bbox_to_anchor=(0.33, 0.8))

# Tiêu đề
plt.title( "Biểu đồ Scatter theo Income và Expenses của các cụm", size=22, color="#FFC300")

plt.show()

# %%
import pandas as pd
import plotly.express as px

# Tạo một bộ dữ liệu mới
clusters_products = df_clusters[['Wines', 'Fruits', 'Meat', 'Fish', 'Sweet', 'Gold', 'cluster']]    # Chọn các biến

clusters_products1 = clusters_products.groupby(['cluster'])
clusters_products2 = clusters_products1.agg({'Wines': 'sum', 'Fruits': 'sum', 'Meat': 'sum', 'Fish': 'sum', 'Sweet': 'sum', 'Gold': 'sum'})

clusters_products3 = clusters_products2.stack().reset_index(name='Count').rename(columns={'level_1': 'Products'})   # phân rã dữ liệu

clusters_products3['group'] = clusters_products3['cluster']
clusters_products3['group'] = clusters_products3['group'].astype(str)


products = clusters_products3.copy()
products = products.assign(ratio=products.groupby('group').Count.transform(lambda x: x / x.sum()))

# Trực quan hóa
fig = px.bar(products, x='group', y='ratio', color='Products',
             labels={
                 "ratio": "Ratio",
                 "group": "Consumer's type"
             },
             color_discrete_map={
                 'Gold': '#FFD700',
                 'Fish': '#87CEEB',
                 'Wines': '#b11226',
                 'Meat': '#f08080',
                 'Sweet': '#FF69B4',
                 'Fruits': 'lightgreen'
             },
             title="Phân bổ các loại sản phẩm theo cụm")

fig.layout.yaxis.tickformat = ',.0%'
fig.update_traces(marker_line_color='white', marker_line_width=1, opacity=0.8)
fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)
fig.update_layout(
    {'plot_bgcolor': 'black',
     'paper_bgcolor': 'black'
     },
    font=dict(
        family="verdana",
        size=21,
        color="white"
    ),
    width=680,
    height=800,
    title_font_color="#FFC300",
    yaxis_title=None,
    xaxis_title=None
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="984cde21-3f87-4175-a4b9-871ba5402f3e" class="plotly-graph-div" style="height:800px; width:680px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("984cde21-3f87-4175-a4b9-871ba5402f3e")) {                    Plotly.newPlot(                        "984cde21-3f87-4175-a4b9-871ba5402f3e",                        [{"alignmentgroup":"True","hovertemplate":"Products=Wines\u003cbr\u003eConsumer's type=%{x}\u003cbr\u003eRatio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wines","marker":{"color":"#b11226","pattern":{"shape":""},"line":{"color":"white","width":1}},"name":"Wines","offsetgroup":"Wines","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3"],"xaxis":"x","y":[0.571973301982446,0.4825369328925378,0.4954197796318669,0.5604459135068559],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"Products=Fruits\u003cbr\u003eConsumer's type=%{x}\u003cbr\u003eRatio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fruits","marker":{"color":"lightgreen","pattern":{"shape":""},"line":{"color":"white","width":1}},"name":"Fruits","offsetgroup":"Fruits","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3"],"xaxis":"x","y":[0.03301795833566599,0.046525075329681725,0.0452221345091728,0.03438611484660726],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"Products=Meat\u003cbr\u003eConsumer's type=%{x}\u003cbr\u003eRatio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Meat","marker":{"color":"#f08080","pattern":{"shape":""},"line":{"color":"white","width":1}},"name":"Meat","offsetgroup":"Meat","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3"],"xaxis":"x","y":[0.20004229881625518,0.2938284557110268,0.28431676138222195,0.20557517563814143],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"Products=Fish\u003cbr\u003eConsumer's type=%{x}\u003cbr\u003eRatio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fish","marker":{"color":"#87CEEB","pattern":{"shape":""},"line":{"color":"white","width":1}},"name":"Fish","offsetgroup":"Fish","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3"],"xaxis":"x","y":[0.050298268858740613,0.06595098386053945,0.06477439089102405,0.04500609549184963],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"Products=Sweet\u003cbr\u003eConsumer's type=%{x}\u003cbr\u003eRatio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sweet","marker":{"color":"#FF69B4","pattern":{"shape":""},"line":{"color":"white","width":1}},"name":"Sweet","offsetgroup":"Sweet","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3"],"xaxis":"x","y":[0.034971168380390764,0.047005721396069435,0.04690273592023831,0.03353148918521497],"yaxis":"y","type":"bar","opacity":0.8},{"alignmentgroup":"True","hovertemplate":"Products=Gold\u003cbr\u003eConsumer's type=%{x}\u003cbr\u003eRatio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gold","marker":{"color":"#FFD700","pattern":{"shape":""},"line":{"color":"white","width":1}},"name":"Gold","offsetgroup":"Gold","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3"],"xaxis":"x","y":[0.10969700362650145,0.0641528308101448,0.063364197665476,0.12105521133133083],"yaxis":"y","type":"bar","opacity":0.8}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0. ...
